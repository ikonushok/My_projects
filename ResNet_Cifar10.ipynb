# %% [markdown]
# <a href="https://colab.research.google.com/github/ikonushok/My_projects/blob/main/ResNet_Cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.models import load_model
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os

import matplotlib.pyplot as plt #Для отрисовки графиков
from PIL import Image #Для отрисовки изображений
import random #Для генерации случайных чисел 

# Training parameters
batch_size = 128#32  # orig paper trained all networks with batch_size=128
epochs = 200
data_augmentation = True
num_classes = 10

# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 5#3

# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 2#1

# %%
# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# %% [markdown]
# ##  Загружаем и нормализуем данные

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %%
#Выводим для примера картинки по каждому классу

fig, axs = plt.subplots(1, 10, figsize=(25, 3)) #Создаем полотно из 10 графиков
for i in range(10): #Проходим по классам от 0 до 9
  label_indexes = np.where(y_train==i)[0] #Получаем список из индексов положений класса i в y_train
  index = random.choice(label_indexes) #Случайным образом выбираем из списка индекс
  img = x_train[index] #Выбираем из x_train нужное изображение
  axs[i].imshow(Image.fromarray(img)) #Отображаем изображение i-ым графиков

plt.show() #Показываем изображения

# %%
# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %% [markdown]
# ## Создаем слои ResNet и функцию замедления скорости

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## Создаем и обучаем ResNet

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
model.summary()
print(model_type)

# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
# Out:
# Learning rate:  0.001
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 16)   448         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 16)   64          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 16)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   272         activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 16)   2320        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 16)   64          conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 16)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   1088        activation[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   1088        activation_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           conv2d_4[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         add[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 16)   1040        activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 16)   64          conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 16)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 16)   2320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 16)   64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 16)   0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   1088        activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           add[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 64)   256         add_1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 16)   1040        activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 16)   64          conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 16)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 16)   2320        activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 16)   64          conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 16)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 64)   1088        activation_8[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 64)   0           add_1[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 64)   256         add_2[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 64)   0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 16)   1040        activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 16)   64          conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 16)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 16)   2320        activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 32, 32, 16)   64          conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 32, 32, 16)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 64)   1088        activation_11[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 32, 32, 64)   0           add_2[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 32, 32, 64)   256         add_3[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 32, 32, 64)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 16)   1040        activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 32, 32, 16)   64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 32, 32, 16)   0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 16)   2320        activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 32, 32, 16)   64          conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 32, 32, 16)   0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 64)   1088        activation_14[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 64)   0           add_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 32, 32, 64)   256         add_4[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 32, 32, 64)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 16, 16, 64)   4160        activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 16, 16, 64)   256         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 16, 16, 64)   0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 16, 16, 64)   36928       activation_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 16, 16, 64)   256         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 16, 16, 64)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 128)  8320        add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 16, 16, 128)  8320        activation_17[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 16, 16, 128)  0           conv2d_20[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 16, 16, 128)  512         add_5[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 16, 16, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 64)   8256        activation_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 16, 16, 64)   256         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 16, 16, 64)   0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 16, 16, 64)   36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 16, 16, 64)   256         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 16, 16, 64)   0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 16, 16, 128)  8320        activation_20[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 128)  0           add_5[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 16, 16, 128)  512         add_6[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 16, 16, 128)  0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 16, 16, 64)   8256        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 64)   256         conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 16, 16, 64)   0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 16, 16, 64)   36928       activation_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 64)   256         conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 16, 16, 64)   0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 16, 16, 128)  8320        activation_23[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 16, 16, 128)  0           add_6[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 16, 16, 128)  512         add_7[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 16, 16, 128)  0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 64)   8256        activation_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 16, 16, 64)   256         conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 16, 16, 64)   0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 16, 16, 64)   36928       activation_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 16, 16, 64)   256         conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 64)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 16, 16, 128)  8320        activation_26[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 128)  0           add_7[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 16, 16, 128)  512         add_8[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 16, 16, 128)  0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 16, 16, 64)   8256        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 16, 16, 64)   256         conv2d_30[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 16, 16, 64)   0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 64)   36928       activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 16, 16, 64)   256         conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 16, 16, 64)   0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 16, 16, 128)  8320        activation_29[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 128)  0           add_8[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 128)  512         add_9[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 128)  0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 8, 8, 128)    16512       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 8, 8, 128)    512         conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 8, 8, 128)    0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 8, 8, 128)    147584      activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 8, 8, 128)    512         conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 8, 8, 128)    0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 8, 8, 256)    33024       add_9[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 8, 8, 256)    33024       activation_32[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 8, 8, 256)    0           conv2d_36[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 8, 8, 256)    1024        add_10[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 8, 8, 256)    0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 8, 8, 128)    32896       activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 8, 8, 128)    512         conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 8, 8, 128)    0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 8, 8, 128)    147584      activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 8, 8, 128)    512         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 8, 8, 128)    0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 8, 8, 256)    33024       activation_35[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 8, 8, 256)    0           add_10[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 8, 8, 256)    1024        add_11[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 8, 8, 256)    0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 8, 8, 128)    32896       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 8, 8, 128)    512         conv2d_40[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 8, 8, 128)    0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 8, 8, 128)    147584      activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 8, 8, 128)    512         conv2d_41[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 8, 8, 128)    0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 8, 8, 256)    33024       activation_38[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 8, 8, 256)    0           add_11[0][0]
#                                                                  conv2d_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 8, 8, 256)    1024        add_12[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 8, 8, 256)    0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 128)    32896       activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 128)    512         conv2d_43[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 8, 8, 128)    0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 128)    147584      activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 128)    512         conv2d_44[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 128)    0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 256)    33024       activation_41[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 8, 8, 256)    0           add_12[0][0]
#                                                                  conv2d_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 256)    1024        add_13[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 256)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 8, 8, 128)    32896       activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 128)    512         conv2d_46[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 128)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 128)    147584      activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 8, 128)    512         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 128)    0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 256)    33024       activation_44[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 256)    0           add_13[0][0]
#                                                                  conv2d_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 256)    1024        add_14[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 256)    0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# average_pooling2d (AveragePooli (None, 1, 1, 256)    0           activation_45[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 256)          0           average_pooling2d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           2570        flatten[0][0]
# ==================================================================================================
# Total params: 1,398,826
# Trainable params: 1,390,154
# Non-trainable params: 8,672
# __________________________________________________________________________________________________
# ResNet47v2

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=None,
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)

    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

    # Fit the model on the batches generated by datagen.flow().
    history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Using real-time data augmentation.
# Epoch 1/200
# Learning rate:  0.001
# 391/391 [==============================] - 45s 95ms/step - loss: 2.4737 - accuracy: 0.4066 - val_loss: 2.2008 - val_accuracy: 0.4341
#
# Epoch 00001: val_accuracy improved from -inf to 0.43410, saving model to /content/saved_models/cifar10_ResNet47v2_model.001.h5
# Epoch 2/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 92ms/step - loss: 1.7017 - accuracy: 0.6044 - val_loss: 1.6362 - val_accuracy: 0.5931
#
# Epoch 00002: val_accuracy improved from 0.43410 to 0.59310, saving model to /content/saved_models/cifar10_ResNet47v2_model.002.h5
# Epoch 3/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 92ms/step - loss: 1.4121 - accuracy: 0.6747 - val_loss: 1.4421 - val_accuracy: 0.6584
#
# Epoch 00003: val_accuracy improved from 0.59310 to 0.65840, saving model to /content/saved_models/cifar10_ResNet47v2_model.003.h5
# Epoch 4/200
# Learning rate:  0.001
# 391/391 [==============================] - 37s 93ms/step - loss: 1.2129 - accuracy: 0.7290 - val_loss: 1.5502 - val_accuracy: 0.6387
#
# Epoch 00004: val_accuracy did not improve from 0.65840
# Epoch 5/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 92ms/step - loss: 1.0898 - accuracy: 0.7623 - val_loss: 1.1492 - val_accuracy: 0.7252
#
# Epoch 00005: val_accuracy improved from 0.65840 to 0.72520, saving model to /content/saved_models/cifar10_ResNet47v2_model.005.h5
# Epoch 6/200
# Learning rate:  0.001
# 391/391 [==============================] - 38s 98ms/step - loss: 1.0117 - accuracy: 0.7821 - val_loss: 1.1449 - val_accuracy: 0.7410
#
# Epoch 00006: val_accuracy improved from 0.72520 to 0.74100, saving model to /content/saved_models/cifar10_ResNet47v2_model.006.h5
# Epoch 7/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.9517 - accuracy: 0.7976 - val_loss: 1.3353 - val_accuracy: 0.6792
#
# Epoch 00007: val_accuracy did not improve from 0.74100
# Epoch 8/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.8985 - accuracy: 0.8098 - val_loss: 1.5457 - val_accuracy: 0.6447
#
# Epoch 00008: val_accuracy did not improve from 0.74100
# Epoch 9/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.8613 - accuracy: 0.8171 - val_loss: 1.1854 - val_accuracy: 0.7253
#
# Epoch 00009: val_accuracy did not improve from 0.74100
# Epoch 10/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.8189 - accuracy: 0.8298 - val_loss: 0.9822 - val_accuracy: 0.7798
#
# Epoch 00010: val_accuracy improved from 0.74100 to 0.77980, saving model to /content/saved_models/cifar10_ResNet47v2_model.010.h5
# Epoch 11/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.7857 - accuracy: 0.8388 - val_loss: 1.2782 - val_accuracy: 0.6981
#
# Epoch 00011: val_accuracy did not improve from 0.77980
# Epoch 12/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.7620 - accuracy: 0.8440 - val_loss: 1.1810 - val_accuracy: 0.7299
#
# Epoch 00012: val_accuracy did not improve from 0.77980
# Epoch 13/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.7391 - accuracy: 0.8524 - val_loss: 0.9847 - val_accuracy: 0.7803
#
# Epoch 00013: val_accuracy improved from 0.77980 to 0.78030, saving model to /content/saved_models/cifar10_ResNet47v2_model.013.h5
# Epoch 14/200
# Learning rate:  0.001
# 391/391 [==============================] - 37s 95ms/step - loss: 0.7078 - accuracy: 0.8584 - val_loss: 0.8322 - val_accuracy: 0.8174
#
# Epoch 00014: val_accuracy improved from 0.78030 to 0.81740, saving model to /content/saved_models/cifar10_ResNet47v2_model.014.h5
# Epoch 15/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.6917 - accuracy: 0.8631 - val_loss: 0.8590 - val_accuracy: 0.8065
#
# Epoch 00015: val_accuracy did not improve from 0.81740
# Epoch 16/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.6789 - accuracy: 0.8650 - val_loss: 0.9757 - val_accuracy: 0.7796
#
# Epoch 00016: val_accuracy did not improve from 0.81740
# Epoch 17/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.6683 - accuracy: 0.8668 - val_loss: 0.7843 - val_accuracy: 0.8348
#
# Epoch 00017: val_accuracy improved from 0.81740 to 0.83480, saving model to /content/saved_models/cifar10_ResNet47v2_model.017.h5
# Epoch 18/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.6382 - accuracy: 0.8759 - val_loss: 1.0230 - val_accuracy: 0.7725
#
# Epoch 00018: val_accuracy did not improve from 0.83480
# Epoch 19/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.6276 - accuracy: 0.8798 - val_loss: 0.9009 - val_accuracy: 0.8007
#
# Epoch 00019: val_accuracy did not improve from 0.83480
# Epoch 20/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.6177 - accuracy: 0.8813 - val_loss: 0.9956 - val_accuracy: 0.7582
#
# Epoch 00020: val_accuracy did not improve from 0.83480
# Epoch 21/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.6094 - accuracy: 0.8825 - val_loss: 0.9329 - val_accuracy: 0.7873
#
# Epoch 00021: val_accuracy did not improve from 0.83480
# Epoch 22/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.5979 - accuracy: 0.8849 - val_loss: 0.7949 - val_accuracy: 0.8212
#
# Epoch 00022: val_accuracy did not improve from 0.83480
# Epoch 23/200
# Learning rate:  0.001
# 391/391 [==============================] - 38s 96ms/step - loss: 0.5882 - accuracy: 0.8875 - val_loss: 0.8224 - val_accuracy: 0.8253
#
# Epoch 00023: val_accuracy did not improve from 0.83480
# Epoch 24/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.5809 - accuracy: 0.8897 - val_loss: 0.8433 - val_accuracy: 0.8101
#
# Epoch 00024: val_accuracy did not improve from 0.83480
# Epoch 25/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.5566 - accuracy: 0.8974 - val_loss: 0.9231 - val_accuracy: 0.7987
#
# Epoch 00025: val_accuracy did not improve from 0.83480
# Epoch 26/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.5578 - accuracy: 0.8957 - val_loss: 0.7570 - val_accuracy: 0.8353
#
# Epoch 00026: val_accuracy improved from 0.83480 to 0.83530, saving model to /content/saved_models/cifar10_ResNet47v2_model.026.h5
# Epoch 27/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.5451 - accuracy: 0.8993 - val_loss: 0.7874 - val_accuracy: 0.8202
#
# Epoch 00027: val_accuracy did not improve from 0.83530
# Epoch 28/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.5481 - accuracy: 0.8972 - val_loss: 0.8091 - val_accuracy: 0.8229
#
# Epoch 00028: val_accuracy did not improve from 0.83530
# Epoch 29/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.5333 - accuracy: 0.9028 - val_loss: 0.7071 - val_accuracy: 0.8464
#
# Epoch 00029: val_accuracy improved from 0.83530 to 0.84640, saving model to /content/saved_models/cifar10_ResNet47v2_model.029.h5
# Epoch 30/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.5279 - accuracy: 0.9022 - val_loss: 0.8673 - val_accuracy: 0.8153
#
# Epoch 00030: val_accuracy did not improve from 0.84640
# Epoch 31/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.5186 - accuracy: 0.9046 - val_loss: 1.0617 - val_accuracy: 0.7702
#
# Epoch 00031: val_accuracy did not improve from 0.84640
# Epoch 32/200
# Learning rate:  0.001
# 391/391 [==============================] - 37s 94ms/step - loss: 0.5123 - accuracy: 0.9088 - val_loss: 0.9600 - val_accuracy: 0.7835
#
# Epoch 00032: val_accuracy did not improve from 0.84640
# Epoch 33/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.5152 - accuracy: 0.9069 - val_loss: 1.0662 - val_accuracy: 0.7729
#
# Epoch 00033: val_accuracy did not improve from 0.84640
# Epoch 34/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.5107 - accuracy: 0.9073 - val_loss: 0.7643 - val_accuracy: 0.8300
#
# Epoch 00034: val_accuracy did not improve from 0.84640
# Epoch 35/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.5031 - accuracy: 0.9087 - val_loss: 0.7349 - val_accuracy: 0.8484
#
# Epoch 00035: val_accuracy improved from 0.84640 to 0.84840, saving model to /content/saved_models/cifar10_ResNet47v2_model.035.h5
# Epoch 36/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.4979 - accuracy: 0.9100 - val_loss: 0.9621 - val_accuracy: 0.7860
#
# Epoch 00036: val_accuracy did not improve from 0.84840
# Epoch 37/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 88ms/step - loss: 0.4900 - accuracy: 0.9143 - val_loss: 0.7071 - val_accuracy: 0.8462
#
# Epoch 00037: val_accuracy did not improve from 0.84840
# Epoch 38/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.4882 - accuracy: 0.9143 - val_loss: 0.8422 - val_accuracy: 0.8175
#
# Epoch 00038: val_accuracy did not improve from 0.84840
# Epoch 39/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 86ms/step - loss: 0.4747 - accuracy: 0.9175 - val_loss: 0.7647 - val_accuracy: 0.8364
#
# Epoch 00039: val_accuracy did not improve from 0.84840
# Epoch 40/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.4753 - accuracy: 0.9160 - val_loss: 0.8096 - val_accuracy: 0.8179
#
# Epoch 00040: val_accuracy did not improve from 0.84840
# Epoch 41/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.4710 - accuracy: 0.9175 - val_loss: 0.8779 - val_accuracy: 0.8072
#
# Epoch 00041: val_accuracy did not improve from 0.84840
# Epoch 42/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.4607 - accuracy: 0.9220 - val_loss: 0.6646 - val_accuracy: 0.8596
#
# Epoch 00042: val_accuracy improved from 0.84840 to 0.85960, saving model to /content/saved_models/cifar10_ResNet47v2_model.042.h5
# Epoch 43/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.4583 - accuracy: 0.9234 - val_loss: 0.6187 - val_accuracy: 0.8740
#
# Epoch 00043: val_accuracy improved from 0.85960 to 0.87400, saving model to /content/saved_models/cifar10_ResNet47v2_model.043.h5
# Epoch 44/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 87ms/step - loss: 0.4624 - accuracy: 0.9192 - val_loss: 0.7253 - val_accuracy: 0.8459
#
# Epoch 00044: val_accuracy did not improve from 0.87400
# Epoch 45/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 85ms/step - loss: 0.4557 - accuracy: 0.9213 - val_loss: 0.7165 - val_accuracy: 0.8462
#
# Epoch 00045: val_accuracy did not improve from 0.87400
# Epoch 46/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 85ms/step - loss: 0.4463 - accuracy: 0.9255 - val_loss: 0.8540 - val_accuracy: 0.8190
#
# Epoch 00046: val_accuracy did not improve from 0.87400
# Epoch 47/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 86ms/step - loss: 0.4488 - accuracy: 0.9231 - val_loss: 0.6805 - val_accuracy: 0.8606
#
# Epoch 00047: val_accuracy did not improve from 0.87400
# Epoch 48/200
# Learning rate:  0.001
# 391/391 [==============================] - 34s 86ms/step - loss: 0.4473 - accuracy: 0.9243 - val_loss: 0.6871 - val_accuracy: 0.8627
#
# Epoch 00048: val_accuracy did not improve from 0.87400
# Epoch 49/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.4359 - accuracy: 0.9274 - val_loss: 0.7463 - val_accuracy: 0.8402
#
# Epoch 00049: val_accuracy did not improve from 0.87400
# Epoch 50/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.4417 - accuracy: 0.9233 - val_loss: 0.7319 - val_accuracy: 0.8495
#
# Epoch 00050: val_accuracy did not improve from 0.87400
# Epoch 51/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.4418 - accuracy: 0.9255 - val_loss: 0.6951 - val_accuracy: 0.8547
#
# Epoch 00051: val_accuracy did not improve from 0.87400
# Epoch 52/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.4342 - accuracy: 0.9285 - val_loss: 0.7594 - val_accuracy: 0.8419
#
# Epoch 00052: val_accuracy did not improve from 0.87400
# Epoch 53/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.4303 - accuracy: 0.9311 - val_loss: 0.7585 - val_accuracy: 0.8391
#
# Epoch 00053: val_accuracy did not improve from 0.87400
# Epoch 54/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.4381 - accuracy: 0.9256 - val_loss: 0.6592 - val_accuracy: 0.8682
#
# Epoch 00054: val_accuracy did not improve from 0.87400
# Epoch 55/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.4294 - accuracy: 0.9304 - val_loss: 0.7133 - val_accuracy: 0.8487
#
# Epoch 00055: val_accuracy did not improve from 0.87400
# Epoch 56/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.4247 - accuracy: 0.9317 - val_loss: 1.1665 - val_accuracy: 0.7719
#
# Epoch 00056: val_accuracy did not improve from 0.87400
# Epoch 57/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.4281 - accuracy: 0.9295 - val_loss: 0.6469 - val_accuracy: 0.8661
#
# Epoch 00057: val_accuracy did not improve from 0.87400
# Epoch 58/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 93ms/step - loss: 0.4193 - accuracy: 0.9314 - val_loss: 0.7485 - val_accuracy: 0.8418
#
# Epoch 00058: val_accuracy did not improve from 0.87400
# Epoch 59/200
# Learning rate:  0.001
# 391/391 [==============================] - 37s 94ms/step - loss: 0.4194 - accuracy: 0.9334 - val_loss: 0.7881 - val_accuracy: 0.8407
#
# Epoch 00059: val_accuracy did not improve from 0.87400
# Epoch 60/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.4092 - accuracy: 0.9361 - val_loss: 0.7891 - val_accuracy: 0.8305
#
# Epoch 00060: val_accuracy did not improve from 0.87400
# Epoch 61/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.4193 - accuracy: 0.9309 - val_loss: 0.6615 - val_accuracy: 0.8645
#
# Epoch 00061: val_accuracy did not improve from 0.87400
# Epoch 62/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.4144 - accuracy: 0.9324 - val_loss: 0.6838 - val_accuracy: 0.8562
#
# Epoch 00062: val_accuracy did not improve from 0.87400
# Epoch 63/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 88ms/step - loss: 0.4028 - accuracy: 0.9390 - val_loss: 0.7028 - val_accuracy: 0.8568
#
# Epoch 00063: val_accuracy did not improve from 0.87400
# Epoch 64/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.3981 - accuracy: 0.9375 - val_loss: 0.6795 - val_accuracy: 0.8641
#
# Epoch 00064: val_accuracy did not improve from 0.87400
# Epoch 65/200
# Learning rate:  0.001
# 391/391 [==============================] - 35s 89ms/step - loss: 0.4114 - accuracy: 0.9333 - val_loss: 0.6920 - val_accuracy: 0.8581
#
# Epoch 00065: val_accuracy did not improve from 0.87400
# Epoch 66/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.4079 - accuracy: 0.9348 - val_loss: 0.7588 - val_accuracy: 0.8482
#
# Epoch 00066: val_accuracy did not improve from 0.87400
# Epoch 67/200
# Learning rate:  0.001
# 391/391 [==============================] - 38s 96ms/step - loss: 0.4034 - accuracy: 0.9355 - val_loss: 0.6808 - val_accuracy: 0.8601
#
# Epoch 00067: val_accuracy did not improve from 0.87400
# Epoch 68/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.4009 - accuracy: 0.9364 - val_loss: 0.7575 - val_accuracy: 0.8458
#
# Epoch 00068: val_accuracy did not improve from 0.87400
# Epoch 69/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.3996 - accuracy: 0.9378 - val_loss: 0.8549 - val_accuracy: 0.8282
#
# Epoch 00069: val_accuracy did not improve from 0.87400
# Epoch 70/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.3901 - accuracy: 0.9394 - val_loss: 0.6958 - val_accuracy: 0.8578
#
# Epoch 00070: val_accuracy did not improve from 0.87400
# Epoch 71/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.3932 - accuracy: 0.9385 - val_loss: 0.8872 - val_accuracy: 0.8107
#
# Epoch 00071: val_accuracy did not improve from 0.87400
# Epoch 72/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.3947 - accuracy: 0.9372 - val_loss: 0.6479 - val_accuracy: 0.8631
#
# Epoch 00072: val_accuracy did not improve from 0.87400
# Epoch 73/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.3924 - accuracy: 0.9381 - val_loss: 0.6963 - val_accuracy: 0.8583
#
# Epoch 00073: val_accuracy did not improve from 0.87400
# Epoch 74/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.3949 - accuracy: 0.9396 - val_loss: 0.6600 - val_accuracy: 0.8743
#
# Epoch 00074: val_accuracy improved from 0.87400 to 0.87430, saving model to /content/saved_models/cifar10_ResNet47v2_model.074.h5
# Epoch 75/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.3925 - accuracy: 0.9381 - val_loss: 0.7077 - val_accuracy: 0.8561
#
# Epoch 00075: val_accuracy did not improve from 0.87430
# Epoch 76/200
# Learning rate:  0.001
# 391/391 [==============================] - 38s 96ms/step - loss: 0.3850 - accuracy: 0.9410 - val_loss: 0.7094 - val_accuracy: 0.8566
#
# Epoch 00076: val_accuracy did not improve from 0.87430
# Epoch 77/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.3825 - accuracy: 0.9408 - val_loss: 0.6128 - val_accuracy: 0.8863
#
# Epoch 00077: val_accuracy improved from 0.87430 to 0.88630, saving model to /content/saved_models/cifar10_ResNet47v2_model.077.h5
# Epoch 78/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.3805 - accuracy: 0.9422 - val_loss: 0.8390 - val_accuracy: 0.8362
#
# Epoch 00078: val_accuracy did not improve from 0.88630
# Epoch 79/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.3898 - accuracy: 0.9400 - val_loss: 0.6296 - val_accuracy: 0.8731
#
# Epoch 00079: val_accuracy did not improve from 0.88630
# Epoch 80/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.3835 - accuracy: 0.9407 - val_loss: 0.6697 - val_accuracy: 0.8570
#
# Epoch 00080: val_accuracy did not improve from 0.88630
# Epoch 81/200
# Learning rate:  0.001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.3894 - accuracy: 0.9394 - val_loss: 0.8356 - val_accuracy: 0.8280
#
# Epoch 00081: val_accuracy did not improve from 0.88630
# Epoch 82/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.3402 - accuracy: 0.9591 - val_loss: 0.4693 - val_accuracy: 0.9175
#
# Epoch 00082: val_accuracy improved from 0.88630 to 0.91750, saving model to /content/saved_models/cifar10_ResNet47v2_model.082.h5
# Epoch 83/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.2938 - accuracy: 0.9732 - val_loss: 0.4709 - val_accuracy: 0.9209
#
# Epoch 00083: val_accuracy improved from 0.91750 to 0.92090, saving model to /content/saved_models/cifar10_ResNet47v2_model.083.h5
# Epoch 84/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.2854 - accuracy: 0.9754 - val_loss: 0.4690 - val_accuracy: 0.9221
#
# Epoch 00084: val_accuracy improved from 0.92090 to 0.92210, saving model to /content/saved_models/cifar10_ResNet47v2_model.084.h5
# Epoch 85/200
# Learning rate:  0.0001
# 391/391 [==============================] - 37s 94ms/step - loss: 0.2710 - accuracy: 0.9791 - val_loss: 0.4646 - val_accuracy: 0.9216
#
# Epoch 00085: val_accuracy did not improve from 0.92210
# Epoch 86/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2661 - accuracy: 0.9805 - val_loss: 0.4663 - val_accuracy: 0.9232
#
# Epoch 00086: val_accuracy improved from 0.92210 to 0.92320, saving model to /content/saved_models/cifar10_ResNet47v2_model.086.h5
# Epoch 87/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2556 - accuracy: 0.9835 - val_loss: 0.4639 - val_accuracy: 0.9228
#
# Epoch 00087: val_accuracy did not improve from 0.92320
# Epoch 88/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2540 - accuracy: 0.9821 - val_loss: 0.4561 - val_accuracy: 0.9242
#
# Epoch 00088: val_accuracy improved from 0.92320 to 0.92420, saving model to /content/saved_models/cifar10_ResNet47v2_model.088.h5
# Epoch 89/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2490 - accuracy: 0.9829 - val_loss: 0.4707 - val_accuracy: 0.9203
#
# Epoch 00089: val_accuracy did not improve from 0.92420
# Epoch 90/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2412 - accuracy: 0.9850 - val_loss: 0.4657 - val_accuracy: 0.9211
#
# Epoch 00090: val_accuracy did not improve from 0.92420
# Epoch 91/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.2382 - accuracy: 0.9848 - val_loss: 0.4710 - val_accuracy: 0.9224
#
# Epoch 00091: val_accuracy did not improve from 0.92420
# Epoch 92/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2309 - accuracy: 0.9872 - val_loss: 0.4647 - val_accuracy: 0.9252
#
# Epoch 00092: val_accuracy improved from 0.92420 to 0.92520, saving model to /content/saved_models/cifar10_ResNet47v2_model.092.h5
# Epoch 93/200
# Learning rate:  0.0001
# 391/391 [==============================] - 38s 95ms/step - loss: 0.2268 - accuracy: 0.9877 - val_loss: 0.4791 - val_accuracy: 0.9203
#
# Epoch 00093: val_accuracy did not improve from 0.92520
# Epoch 94/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.2239 - accuracy: 0.9875 - val_loss: 0.4772 - val_accuracy: 0.9203
#
# Epoch 00094: val_accuracy did not improve from 0.92520
# Epoch 95/200
# Learning rate:  0.0001
# 391/391 [==============================] - 35s 90ms/step - loss: 0.2187 - accuracy: 0.9892 - val_loss: 0.4799 - val_accuracy: 0.9199
#
# Epoch 00095: val_accuracy did not improve from 0.92520
# Epoch 96/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.2152 - accuracy: 0.9897 - val_loss: 0.4754 - val_accuracy: 0.9228
#
# Epoch 00096: val_accuracy did not improve from 0.92520
# Epoch 97/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2155 - accuracy: 0.9882 - val_loss: 0.4687 - val_accuracy: 0.9223
#
# Epoch 00097: val_accuracy did not improve from 0.92520
# Epoch 98/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2099 - accuracy: 0.9897 - val_loss: 0.4794 - val_accuracy: 0.9210
#
# Epoch 00098: val_accuracy did not improve from 0.92520
# Epoch 99/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2037 - accuracy: 0.9919 - val_loss: 0.4882 - val_accuracy: 0.9194
#
# Epoch 00099: val_accuracy did not improve from 0.92520
# Epoch 100/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 93ms/step - loss: 0.2037 - accuracy: 0.9905 - val_loss: 0.4767 - val_accuracy: 0.9210
#
# Epoch 00100: val_accuracy did not improve from 0.92520
# Epoch 101/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.2006 - accuracy: 0.9912 - val_loss: 0.4693 - val_accuracy: 0.9224
#
# Epoch 00101: val_accuracy did not improve from 0.92520
# Epoch 102/200
# Learning rate:  0.0001
# 391/391 [==============================] - 38s 96ms/step - loss: 0.1977 - accuracy: 0.9912 - val_loss: 0.4772 - val_accuracy: 0.9238
#
# Epoch 00102: val_accuracy did not improve from 0.92520
# Epoch 103/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1967 - accuracy: 0.9909 - val_loss: 0.4747 - val_accuracy: 0.9235
#
# Epoch 00103: val_accuracy did not improve from 0.92520
# Epoch 104/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1938 - accuracy: 0.9914 - val_loss: 0.4849 - val_accuracy: 0.9222
#
# Epoch 00104: val_accuracy did not improve from 0.92520
# Epoch 105/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1913 - accuracy: 0.9918 - val_loss: 0.4664 - val_accuracy: 0.9252
#
# Epoch 00105: val_accuracy did not improve from 0.92520
# Epoch 106/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1886 - accuracy: 0.9924 - val_loss: 0.5020 - val_accuracy: 0.9197
#
# Epoch 00106: val_accuracy did not improve from 0.92520
# Epoch 107/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1864 - accuracy: 0.9928 - val_loss: 0.4801 - val_accuracy: 0.9228
#
# Epoch 00107: val_accuracy did not improve from 0.92520
# Epoch 108/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1853 - accuracy: 0.9925 - val_loss: 0.4808 - val_accuracy: 0.9219
#
# Epoch 00108: val_accuracy did not improve from 0.92520
# Epoch 109/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1833 - accuracy: 0.9928 - val_loss: 0.4857 - val_accuracy: 0.9209
#
# Epoch 00109: val_accuracy did not improve from 0.92520
# Epoch 110/200
# Learning rate:  0.0001
# 391/391 [==============================] - 38s 96ms/step - loss: 0.1796 - accuracy: 0.9937 - val_loss: 0.4844 - val_accuracy: 0.9221
#
# Epoch 00110: val_accuracy did not improve from 0.92520
# Epoch 111/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1803 - accuracy: 0.9922 - val_loss: 0.4902 - val_accuracy: 0.9241
#
# Epoch 00111: val_accuracy did not improve from 0.92520
# Epoch 112/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1774 - accuracy: 0.9928 - val_loss: 0.4730 - val_accuracy: 0.9228
#
# Epoch 00112: val_accuracy did not improve from 0.92520
# Epoch 113/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1744 - accuracy: 0.9939 - val_loss: 0.4959 - val_accuracy: 0.9219
#
# Epoch 00113: val_accuracy did not improve from 0.92520
# Epoch 114/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1737 - accuracy: 0.9934 - val_loss: 0.4835 - val_accuracy: 0.9257
#
# Epoch 00114: val_accuracy improved from 0.92520 to 0.92570, saving model to /content/saved_models/cifar10_ResNet47v2_model.114.h5
# Epoch 115/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1723 - accuracy: 0.9934 - val_loss: 0.4896 - val_accuracy: 0.9218
#
# Epoch 00115: val_accuracy did not improve from 0.92570
# Epoch 116/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1702 - accuracy: 0.9933 - val_loss: 0.4727 - val_accuracy: 0.9229
#
# Epoch 00116: val_accuracy did not improve from 0.92570
# Epoch 117/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 93ms/step - loss: 0.1687 - accuracy: 0.9940 - val_loss: 0.4800 - val_accuracy: 0.9256
#
# Epoch 00117: val_accuracy did not improve from 0.92570
# Epoch 118/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1677 - accuracy: 0.9936 - val_loss: 0.4852 - val_accuracy: 0.9243
#
# Epoch 00118: val_accuracy did not improve from 0.92570
# Epoch 119/200
# Learning rate:  0.0001
# 391/391 [==============================] - 38s 96ms/step - loss: 0.1681 - accuracy: 0.9928 - val_loss: 0.4847 - val_accuracy: 0.9233
#
# Epoch 00119: val_accuracy did not improve from 0.92570
# Epoch 120/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1624 - accuracy: 0.9945 - val_loss: 0.5108 - val_accuracy: 0.9205
#
# Epoch 00120: val_accuracy did not improve from 0.92570
# Epoch 121/200
# Learning rate:  0.0001
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1620 - accuracy: 0.9944 - val_loss: 0.5062 - val_accuracy: 0.9222
#
# Epoch 00121: val_accuracy did not improve from 0.92570
# Epoch 122/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1607 - accuracy: 0.9938 - val_loss: 0.4859 - val_accuracy: 0.9263
#
# Epoch 00122: val_accuracy improved from 0.92570 to 0.92630, saving model to /content/saved_models/cifar10_ResNet47v2_model.122.h5
# Epoch 123/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1579 - accuracy: 0.9956 - val_loss: 0.4813 - val_accuracy: 0.9266
#
# Epoch 00123: val_accuracy improved from 0.92630 to 0.92660, saving model to /content/saved_models/cifar10_ResNet47v2_model.123.h5
# Epoch 124/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1577 - accuracy: 0.9953 - val_loss: 0.4761 - val_accuracy: 0.9270
#
# Epoch 00124: val_accuracy improved from 0.92660 to 0.92700, saving model to /content/saved_models/cifar10_ResNet47v2_model.124.h5
# Epoch 125/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1564 - accuracy: 0.9958 - val_loss: 0.4757 - val_accuracy: 0.9265
#
# Epoch 00125: val_accuracy did not improve from 0.92700
# Epoch 126/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1559 - accuracy: 0.9956 - val_loss: 0.4747 - val_accuracy: 0.9276
#
# Epoch 00126: val_accuracy improved from 0.92700 to 0.92760, saving model to /content/saved_models/cifar10_ResNet47v2_model.126.h5
# Epoch 127/200
# Learning rate:  1e-05
# 391/391 [==============================] - 37s 93ms/step - loss: 0.1542 - accuracy: 0.9967 - val_loss: 0.4726 - val_accuracy: 0.9278
#
# Epoch 00127: val_accuracy improved from 0.92760 to 0.92780, saving model to /content/saved_models/cifar10_ResNet47v2_model.127.h5
# Epoch 128/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1531 - accuracy: 0.9972 - val_loss: 0.4704 - val_accuracy: 0.9279
#
# Epoch 00128: val_accuracy improved from 0.92780 to 0.92790, saving model to /content/saved_models/cifar10_ResNet47v2_model.128.h5
# Epoch 129/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1534 - accuracy: 0.9965 - val_loss: 0.4743 - val_accuracy: 0.9269
#
# Epoch 00129: val_accuracy did not improve from 0.92790
# Epoch 130/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1534 - accuracy: 0.9969 - val_loss: 0.4742 - val_accuracy: 0.9275
#
# Epoch 00130: val_accuracy did not improve from 0.92790
# Epoch 131/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1530 - accuracy: 0.9966 - val_loss: 0.4731 - val_accuracy: 0.9272
#
# Epoch 00131: val_accuracy did not improve from 0.92790
# Epoch 132/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1512 - accuracy: 0.9976 - val_loss: 0.4738 - val_accuracy: 0.9283
#
# Epoch 00132: val_accuracy improved from 0.92790 to 0.92830, saving model to /content/saved_models/cifar10_ResNet47v2_model.132.h5
# Epoch 133/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1522 - accuracy: 0.9969 - val_loss: 0.4748 - val_accuracy: 0.9272
#
# Epoch 00133: val_accuracy did not improve from 0.92830
# Epoch 134/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1518 - accuracy: 0.9969 - val_loss: 0.4749 - val_accuracy: 0.9277
#
# Epoch 00134: val_accuracy did not improve from 0.92830
# Epoch 135/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1507 - accuracy: 0.9975 - val_loss: 0.4697 - val_accuracy: 0.9283
#
# Epoch 00135: val_accuracy did not improve from 0.92830
# Epoch 136/200
# Learning rate:  1e-05
# 391/391 [==============================] - 38s 96ms/step - loss: 0.1516 - accuracy: 0.9969 - val_loss: 0.4732 - val_accuracy: 0.9280
#
# Epoch 00136: val_accuracy did not improve from 0.92830
# Epoch 137/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1513 - accuracy: 0.9970 - val_loss: 0.4706 - val_accuracy: 0.9281
#
# Epoch 00137: val_accuracy did not improve from 0.92830
# Epoch 138/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1506 - accuracy: 0.9969 - val_loss: 0.4731 - val_accuracy: 0.9268
#
# Epoch 00138: val_accuracy did not improve from 0.92830
# Epoch 139/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1504 - accuracy: 0.9974 - val_loss: 0.4723 - val_accuracy: 0.9283
#
# Epoch 00139: val_accuracy did not improve from 0.92830
# Epoch 140/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1496 - accuracy: 0.9971 - val_loss: 0.4721 - val_accuracy: 0.9280
#
# Epoch 00140: val_accuracy did not improve from 0.92830
# Epoch 141/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1495 - accuracy: 0.9968 - val_loss: 0.4735 - val_accuracy: 0.9284
#
# Epoch 00141: val_accuracy improved from 0.92830 to 0.92840, saving model to /content/saved_models/cifar10_ResNet47v2_model.141.h5
# Epoch 142/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1487 - accuracy: 0.9978 - val_loss: 0.4744 - val_accuracy: 0.9275
#
# Epoch 00142: val_accuracy did not improve from 0.92840
# Epoch 143/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1491 - accuracy: 0.9976 - val_loss: 0.4731 - val_accuracy: 0.9282
#
# Epoch 00143: val_accuracy did not improve from 0.92840
# Epoch 144/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1476 - accuracy: 0.9977 - val_loss: 0.4740 - val_accuracy: 0.9295
#
# Epoch 00144: val_accuracy improved from 0.92840 to 0.92950, saving model to /content/saved_models/cifar10_ResNet47v2_model.144.h5
# Epoch 145/200
# Learning rate:  1e-05
# 391/391 [==============================] - 38s 95ms/step - loss: 0.1484 - accuracy: 0.9976 - val_loss: 0.4752 - val_accuracy: 0.9278
#
# Epoch 00145: val_accuracy did not improve from 0.92950
# Epoch 146/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1480 - accuracy: 0.9980 - val_loss: 0.4745 - val_accuracy: 0.9286
#
# Epoch 00146: val_accuracy did not improve from 0.92950
# Epoch 147/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1473 - accuracy: 0.9977 - val_loss: 0.4747 - val_accuracy: 0.9280
#
# Epoch 00147: val_accuracy did not improve from 0.92950
# Epoch 148/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1475 - accuracy: 0.9976 - val_loss: 0.4742 - val_accuracy: 0.9269
#
# Epoch 00148: val_accuracy did not improve from 0.92950
# Epoch 149/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1477 - accuracy: 0.9976 - val_loss: 0.4749 - val_accuracy: 0.9282
#
# Epoch 00149: val_accuracy did not improve from 0.92950
# Epoch 150/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1467 - accuracy: 0.9978 - val_loss: 0.4751 - val_accuracy: 0.9272
#
# Epoch 00150: val_accuracy did not improve from 0.92950
# Epoch 151/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1461 - accuracy: 0.9979 - val_loss: 0.4745 - val_accuracy: 0.9280
#
# Epoch 00151: val_accuracy did not improve from 0.92950
# Epoch 152/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1470 - accuracy: 0.9972 - val_loss: 0.4754 - val_accuracy: 0.9285
#
# Epoch 00152: val_accuracy did not improve from 0.92950
# Epoch 153/200
# Learning rate:  1e-05
# 391/391 [==============================] - 38s 96ms/step - loss: 0.1454 - accuracy: 0.9983 - val_loss: 0.4754 - val_accuracy: 0.9286
#
# Epoch 00153: val_accuracy did not improve from 0.92950
# Epoch 154/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1446 - accuracy: 0.9985 - val_loss: 0.4776 - val_accuracy: 0.9274
#
# Epoch 00154: val_accuracy did not improve from 0.92950
# Epoch 155/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1462 - accuracy: 0.9973 - val_loss: 0.4786 - val_accuracy: 0.9274
#
# Epoch 00155: val_accuracy did not improve from 0.92950
# Epoch 156/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1448 - accuracy: 0.9979 - val_loss: 0.4803 - val_accuracy: 0.9276
#
# Epoch 00156: val_accuracy did not improve from 0.92950
# Epoch 157/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1448 - accuracy: 0.9980 - val_loss: 0.4793 - val_accuracy: 0.9269
#
# Epoch 00157: val_accuracy did not improve from 0.92950
# Epoch 158/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1452 - accuracy: 0.9976 - val_loss: 0.4787 - val_accuracy: 0.9279
#
# Epoch 00158: val_accuracy did not improve from 0.92950
# Epoch 159/200
# Learning rate:  1e-05
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1447 - accuracy: 0.9980 - val_loss: 0.4766 - val_accuracy: 0.9282
#
# Epoch 00159: val_accuracy did not improve from 0.92950
# Epoch 160/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1440 - accuracy: 0.9978 - val_loss: 0.4822 - val_accuracy: 0.9271
#
# Epoch 00160: val_accuracy did not improve from 0.92950
# Epoch 161/200
# Learning rate:  1e-05
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1448 - accuracy: 0.9977 - val_loss: 0.4794 - val_accuracy: 0.9269
#
# Epoch 00161: val_accuracy did not improve from 0.92950
# Epoch 162/200
# Learning rate:  1e-06
# 391/391 [==============================] - 37s 94ms/step - loss: 0.1436 - accuracy: 0.9978 - val_loss: 0.4780 - val_accuracy: 0.9271
#
# Epoch 00162: val_accuracy did not improve from 0.92950
# Epoch 163/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1438 - accuracy: 0.9975 - val_loss: 0.4792 - val_accuracy: 0.9268
#
# Epoch 00163: val_accuracy did not improve from 0.92950
# Epoch 164/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1432 - accuracy: 0.9984 - val_loss: 0.4781 - val_accuracy: 0.9269
#
# Epoch 00164: val_accuracy did not improve from 0.92950
# Epoch 165/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1436 - accuracy: 0.9978 - val_loss: 0.4783 - val_accuracy: 0.9271
#
# Epoch 00165: val_accuracy did not improve from 0.92950
# Epoch 166/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1445 - accuracy: 0.9973 - val_loss: 0.4782 - val_accuracy: 0.9269
#
# Epoch 00166: val_accuracy did not improve from 0.92950
# Epoch 167/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1443 - accuracy: 0.9977 - val_loss: 0.4781 - val_accuracy: 0.9270
#
# Epoch 00167: val_accuracy did not improve from 0.92950
# Epoch 168/200
# Learning rate:  1e-06
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1442 - accuracy: 0.9974 - val_loss: 0.4777 - val_accuracy: 0.9272
#
# Epoch 00168: val_accuracy did not improve from 0.92950
# Epoch 169/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1434 - accuracy: 0.9981 - val_loss: 0.4775 - val_accuracy: 0.9266
#
# Epoch 00169: val_accuracy did not improve from 0.92950
# Epoch 170/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1437 - accuracy: 0.9978 - val_loss: 0.4771 - val_accuracy: 0.9276
#
# Epoch 00170: val_accuracy did not improve from 0.92950
# Epoch 171/200
# Learning rate:  1e-06
# 391/391 [==============================] - 37s 94ms/step - loss: 0.1431 - accuracy: 0.9982 - val_loss: 0.4766 - val_accuracy: 0.9271
#
# Epoch 00171: val_accuracy did not improve from 0.92950
# Epoch 172/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1431 - accuracy: 0.9978 - val_loss: 0.4780 - val_accuracy: 0.9277
#
# Epoch 00172: val_accuracy did not improve from 0.92950
# Epoch 173/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1436 - accuracy: 0.9978 - val_loss: 0.4789 - val_accuracy: 0.9274
#
# Epoch 00173: val_accuracy did not improve from 0.92950
# Epoch 174/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1431 - accuracy: 0.9984 - val_loss: 0.4779 - val_accuracy: 0.9273
#
# Epoch 00174: val_accuracy did not improve from 0.92950
# Epoch 175/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 89ms/step - loss: 0.1427 - accuracy: 0.9983 - val_loss: 0.4773 - val_accuracy: 0.9275
#
# Epoch 00175: val_accuracy did not improve from 0.92950
# Epoch 176/200
# Learning rate:  1e-06
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1437 - accuracy: 0.9976 - val_loss: 0.4770 - val_accuracy: 0.9272
#
# Epoch 00176: val_accuracy did not improve from 0.92950
# Epoch 177/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1433 - accuracy: 0.9977 - val_loss: 0.4773 - val_accuracy: 0.9270
#
# Epoch 00177: val_accuracy did not improve from 0.92950
# Epoch 178/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1431 - accuracy: 0.9981 - val_loss: 0.4770 - val_accuracy: 0.9272
#
# Epoch 00178: val_accuracy did not improve from 0.92950
# Epoch 179/200
# Learning rate:  1e-06
# 391/391 [==============================] - 37s 93ms/step - loss: 0.1426 - accuracy: 0.9985 - val_loss: 0.4779 - val_accuracy: 0.9274
#
# Epoch 00179: val_accuracy did not improve from 0.92950
# Epoch 180/200
# Learning rate:  1e-06
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1427 - accuracy: 0.9983 - val_loss: 0.4773 - val_accuracy: 0.9272
#
# Epoch 00180: val_accuracy did not improve from 0.92950
# Epoch 181/200
# Learning rate:  1e-06
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1440 - accuracy: 0.9978 - val_loss: 0.4770 - val_accuracy: 0.9276
#
# Epoch 00181: val_accuracy did not improve from 0.92950
# Epoch 182/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1444 - accuracy: 0.9975 - val_loss: 0.4775 - val_accuracy: 0.9275
#
# Epoch 00182: val_accuracy did not improve from 0.92950
# Epoch 183/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1425 - accuracy: 0.9981 - val_loss: 0.4773 - val_accuracy: 0.9277
#
# Epoch 00183: val_accuracy did not improve from 0.92950
# Epoch 184/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1434 - accuracy: 0.9980 - val_loss: 0.4761 - val_accuracy: 0.9276
#
# Epoch 00184: val_accuracy did not improve from 0.92950
# Epoch 185/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1445 - accuracy: 0.9972 - val_loss: 0.4769 - val_accuracy: 0.9275
#
# Epoch 00185: val_accuracy did not improve from 0.92950
# Epoch 186/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1430 - accuracy: 0.9983 - val_loss: 0.4776 - val_accuracy: 0.9272
#
# Epoch 00186: val_accuracy did not improve from 0.92950
# Epoch 187/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1431 - accuracy: 0.9979 - val_loss: 0.4786 - val_accuracy: 0.9270
#
# Epoch 00187: val_accuracy did not improve from 0.92950
# Epoch 188/200
# Learning rate:  5e-07
# 391/391 [==============================] - 37s 95ms/step - loss: 0.1430 - accuracy: 0.9980 - val_loss: 0.4777 - val_accuracy: 0.9270
#
# Epoch 00188: val_accuracy did not improve from 0.92950
# Epoch 189/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1442 - accuracy: 0.9975 - val_loss: 0.4773 - val_accuracy: 0.9271
#
# Epoch 00189: val_accuracy did not improve from 0.92950
# Epoch 190/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1433 - accuracy: 0.9976 - val_loss: 0.4774 - val_accuracy: 0.9275
#
# Epoch 00190: val_accuracy did not improve from 0.92950
# Epoch 191/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1426 - accuracy: 0.9982 - val_loss: 0.4782 - val_accuracy: 0.9274
#
# Epoch 00191: val_accuracy did not improve from 0.92950
# Epoch 192/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1437 - accuracy: 0.9978 - val_loss: 0.4775 - val_accuracy: 0.9277
#
# Epoch 00192: val_accuracy did not improve from 0.92950
# Epoch 193/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 92ms/step - loss: 0.1428 - accuracy: 0.9980 - val_loss: 0.4783 - val_accuracy: 0.9280
#
# Epoch 00193: val_accuracy did not improve from 0.92950
# Epoch 194/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1436 - accuracy: 0.9979 - val_loss: 0.4784 - val_accuracy: 0.9278
#
# Epoch 00194: val_accuracy did not improve from 0.92950
# Epoch 195/200
# Learning rate:  5e-07
# 391/391 [==============================] - 35s 90ms/step - loss: 0.1439 - accuracy: 0.9975 - val_loss: 0.4780 - val_accuracy: 0.9273
#
# Epoch 00195: val_accuracy did not improve from 0.92950
# Epoch 196/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1421 - accuracy: 0.9984 - val_loss: 0.4778 - val_accuracy: 0.9273
#
# Epoch 00196: val_accuracy did not improve from 0.92950
# Epoch 197/200
# Learning rate:  5e-07
# 391/391 [==============================] - 37s 95ms/step - loss: 0.1431 - accuracy: 0.9982 - val_loss: 0.4774 - val_accuracy: 0.9276
#
# Epoch 00197: val_accuracy did not improve from 0.92950
# Epoch 198/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 90ms/step - loss: 0.1429 - accuracy: 0.9982 - val_loss: 0.4773 - val_accuracy: 0.9274
#
# Epoch 00198: val_accuracy did not improve from 0.92950
# Epoch 199/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1422 - accuracy: 0.9984 - val_loss: 0.4768 - val_accuracy: 0.9273
#
# Epoch 00199: val_accuracy did not improve from 0.92950
# Epoch 200/200
# Learning rate:  5e-07
# 391/391 [==============================] - 36s 91ms/step - loss: 0.1428 - accuracy: 0.9981 - val_loss: 0.4777 - val_accuracy: 0.9273
#
# Epoch 00200: val_accuracy did not improve from 0.92950

# %%
# Score trained model.
#model_name = '/content/saved_models/cifar10_ResNet47v2_model.144.h5'

scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 313/313 [==============================] - 2s 7ms/step - loss: 0.4777 - accuracy: 0.9273
# Test loss: 0.4776660203933716
# Test accuracy: 0.927299976348877

# %%
# Отображаем график точности обучения
plt.plot(history.history['accuracy'], label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'], label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %% [markdown]
# ## Проверяем обучение

# %%
model_name = '/content/saved_models/cifar10_ResNet47v2_model.144.h5'

# %%
# Load the CIFAR10 data.
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

# Normalize data.
x_train = X_train.astype('float32') / 255
x_test = X_test.astype('float32') / 255

# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
#Определяем названия классов по порядку
classes = ['самолет', 'автомобиль', 'птица', 'кот', 'олень', 'собака', 'лягушка', 'лошадь', 'корабль', 'грузовик']

# %%
prediction = model.predict(x_test) #Классифицируем каждое изображение
for i in range(10): #Проходим по картинкам
  #Вводим результаты на экран
  print("Распознанный образ:", classes[np.argmax(prediction[i])])
  print('Верный ответ:', classes[y_test[i][0]])
  print()
# Out:
# Распознанный образ: кот
# Верный ответ: кот
#
# Распознанный образ: корабль
# Верный ответ: корабль
#
# Распознанный образ: корабль
# Верный ответ: корабль
#
# Распознанный образ: самолет
# Верный ответ: самолет
#
# Распознанный образ: лягушка
# Верный ответ: лягушка
#
# Распознанный образ: лягушка
# Верный ответ: лягушка
#
# Распознанный образ: автомобиль
# Верный ответ: автомобиль
#
# Распознанный образ: лягушка
# Верный ответ: лягушка
#
# Распознанный образ: кот
# Верный ответ: кот
#
# Распознанный образ: автомобиль
# Верный ответ: автомобиль

# %%
prediction = model.predict(x_test) #Классифицируем каждое изображение

for n in range(10):
  #Выводим на экран картинку
  plt.imshow(Image.fromarray(X_test[n]).convert('RGBA'))
  plt.show()

  #Выводим на экран результаты
  #print("Выход сети: ", prediction[x_test[n]])
  print("Распознанный образ: ", np.argmax(prediction[n]))
  print("Верный ответ: ", y_test[n])
  print("Распознанный браз на картинке: ", classes[np.argmax(prediction[n])])
# Out:
# Распознанный образ:  3
# Верный ответ:  [3]
# Распознанный браз на картинке:  кот
# Распознанный образ:  8
# Верный ответ:  [8]
# Распознанный браз на картинке:  корабль
# Распознанный образ:  8
# Верный ответ:  [8]
# Распознанный браз на картинке:  корабль
# Распознанный образ:  0
# Верный ответ:  [0]
# Распознанный браз на картинке:  самолет
# Распознанный образ:  6
# Верный ответ:  [6]
# Распознанный браз на картинке:  лягушка
# Распознанный образ:  6
# Верный ответ:  [6]
# Распознанный браз на картинке:  лягушка
# Распознанный образ:  1
# Верный ответ:  [1]
# Распознанный браз на картинке:  автомобиль
# Распознанный образ:  6
# Верный ответ:  [6]
# Распознанный браз на картинке:  лягушка
# Распознанный образ:  3
# Верный ответ:  [3]
# Распознанный браз на картинке:  кот
# Распознанный образ:  1
# Верный ответ:  [1]
# Распознанный браз на картинке:  автомобиль

# %%
#Выбираем номер пример
n = 2027

#Выводим на экран картинку
plt.imshow(Image.fromarray(X_test[n]).convert('RGBA'))
plt.show()

#Выводим на экран результаты
print("Выход сети: ", prediction[n])
print("Распознанный образ: ", np.argmax(prediction[n]))
print("Верный ответ: ", y_test[n])
print("Распознанный браз на картинке: ", classes[np.argmax(prediction[n])])
# Out:
# Выход сети:  [6.6653455e-10 1.8479243e-08 3.6798491e-11 3.0552314e-08 1.6667790e-11
#  2.0140052e-10 6.0082722e-10 7.3724349e-10 3.6451415e-09 1.0000000e+00]
# Распознанный образ:  9
# Верный ответ:  [9]
# Распознанный браз на картинке:  грузовик
